# %% [markdown]
# 1) What is difference between List and a SET?

# %%
print(5+10)
# Out:
# 15

# %% [markdown]
# 1. What is mutable?
#     - changable -> set, list,dict

# %%
x=[]
y=10
x[0]=y
print(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 x=[]
#       2 y=10
# ----> 3 x[0]=y
#       4 print(x)
#
# IndexError: list assignment index out of range

# %%
x=[]
y=10
x.append(y)
print(x)
# Out:
# [10]

# %%
x={"name":"gokul"}
x["name"]="neelima"
x["samhita"]="collection of ancient knowledge"
print(type(x))
print(x)
# Out:
# <class 'dict'>
# {'name': 'neelima', 'samhita': 'collection of ancient knowledge'}

# %%
x=set()
x.add("123")
print(x)
# Out:
# {'123'}

# %%
# gokul please remeber
x=()
print(type(x))
# Out:
# <class 'tuple'>

# %%
# x=1,2
x=(1,)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x=(1,2,3)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={1,2,3,"rajawat"}
print(type(x))
# Out:
# <class 'set'>

# %% [markdown]
# - set and list both are mutable
# - set can have differnt data types inside just like a list
#
# - `set cant have duplicates`

# %%
x={1,2,2,3}
print(len(x))
# Out:
# 3

# %% [markdown]
# ### what are keywords in python
#    - reserved words
#    - special purpose
#    - `cannot be used as a variable`
#    - pass, return , print

# %% [markdown]
# - `int` is not a keywork, we can use it as a variable

# %%
# pass=10
break=10
x=10
# Out:
#   Cell In[23], line 1
#     pass=10
#         ^
# SyntaxError: invalid syntax

# %%
assert 11==11
